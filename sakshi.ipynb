# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.read_csv('Saree-Retailer-Database.csv')
df
# Out:
#     index                            Saree Retailer Database  \
# 0       0              10,000 Saree Retailer Data: Rs.2199/-
# 1       1                                    Purchase Link:
# 2       2                                         Email Id:
# 3       3                              Call or Whatsapp No:
# 4       4                                          Website:
# ..    ...                                                ...
# 57     57  Purchase Link: http://www.ecommercedatabase.in...
# 58     58           Email Id: ecommercedatabase.in@gmail.com
# 59     59                 Call or Whatsapp No: +917042661668
# 60     60                  Website: www.ecommercedatabase.in
# 61     61                                                NaN
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                 NaN        NaN        NaN
# 1   https://www.ecommercedatabase.in/All-india-Cat...        NaN        NaN
# ...

# %%
df.shape
# Out:
# (62, 28)

# %%
len(df)
# Out:
# 62

# %%
df.head(3)
# Out:
#    index                Saree Retailer Database  \
# 0      0  10,000 Saree Retailer Data: Rs.2199/-
# 1      1                        Purchase Link:
# 2      2                             Email Id:
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                NaN        NaN        NaN
# 1  https://www.ecommercedatabase.in/All-india-Cat...        NaN        NaN
# 2                     ecommercedatabase.in@gmail.com        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  ... Unnamed: 17  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 2        NaN        NaN        NaN        NaN        NaN  ...         NaN
#
#   Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
df.tail(3)
# Out:
#     index             Saree Retailer Database Unnamed: 1 Unnamed: 2  \
# 59     59  Call or Whatsapp No: +917042661668        NaN        NaN
# 60     60   Website: www.ecommercedatabase.in        NaN        NaN
# 61     61                                 NaN        NaN        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  ...  \
# 59        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 60        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 61        NaN        NaN        NaN        NaN        NaN        NaN  ...
#
#    Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 59         NaN         NaN         NaN         NaN         NaN         NaN
# 60         NaN         NaN         NaN         NaN         NaN         NaN
# 61         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# ...

# %%
df[df['index']=='0'].head(2)
# Out:
# Empty DataFrame
# Columns: [index, Saree Retailer Database, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20, Unnamed: 21, Unnamed: 22, Unnamed: 23, Unnamed: 24, Unnamed: 25, Unnamed: 26]
# Index: []
#
# [0 rows x 28 columns]
